# %% [markdown]
#  ___
# # Atividade: Modelos probabilísticos discretos
# ___
#
# ## Aula 12
#
# **Referência de Leitura:**
# 1. Magalhães e Lima (7ª. Edição): Seções 3.2 e 3.3
#
# **Hoje:**
# 1.	Descrever modelos discretos quanto aos resultados teóricos.
# 2.	Explicar a utilização de modelos probabilísticos no contexto da literatura estatística.
# 3.	Contrastar resultados teóricos e empíricos.
# 4.	Fechamento do conteúdo.
#
# **Próxima aula:**
# 1. Leitura prévia necessária: Magalhães e Lima (7ª. Edição): Capítulo 6 - Seção 6.1.
#
# ___

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

from scipy import stats #importa apenas as funções de estatísticas da biblioteca SciPy.
import itertools #importante para gerar todos os resultados possíveis!!

# %% [markdown]
# ___
# ## <font color='blue'>Exercício 1</font>
#
# ### <font color='red'>**Publicar no github até dia 10/04 INDIVIDUAL **</font>
#
#
# #### Este exercício irá explorar  construção de árvore de probabilidades com eventos e construção da distribuição de probabilidades de uma variável aleatória discreta. Ainda, irá explorar o modelo de distribuição probabilística Binomial
#
# Um resistor de 100K Ohms comprado na Santa Efigênia tem probabilidade de falha de 5%, segundo um fabricante ruim.
#
# Ainda, por suposição, admita que os resistores falhem de forma independente entre si.
#
# Um aluno de engenharia compra um pacote contendo $n$ resistores.
#
# 1. Assuma $n=3$ e faça os itens a seguir.
#   1. Monte o espaço amostral que combine todos os resultados possíveis de Falha e não Falha desses $n$ resistores. Ainda, calcule a probabilidade de cada resultado do espaço amostral acontecer.
#   2. Se $Y$ representa o número de resistores que falham em um pacotinho com $n$ resistores, então construa a distribuição de probabilidades de $Y$.
#   3. Calcule a média e o desvio padrão de $Y$. Interprete os resultados.
#   4. Utilizando o modelo probabilístico da distribuição Binomial, encontre a distribuição de probabilidades de cada possível valor de $Y$. Calcule também $E(Y)$ e $Var(Y)$. Compare com as distribuições de probabilidades obtidas nos itens anteriores e discuta porque esses valores são iguais ou diferentes!
#
# 2. Assuma $n=7$ e repita os itens A) a D) anteriores. No caso de $n=7$ ou maiores quantidades de resistores em um pacotinho, qual a viabilidade de construir a distribuição de probabilidades do número de resistores com defeitos quando $n$ não é pequeno seguindo os itens de A) a C)?
#
# 3. Com $n=100$, por exemplo, é extremamente inviável a construção de árvore de probabilidades até mesmo utilizando a poderosa ferramenta Python.
#   1. No caso assuma $n=100$ e repita o item 1.D) anterior.
#   2. Ainda, calcule a probabilidade de, em um pacote com 100 resistores, pelo menos a metade deles apresentarem falha?
#
#
# A seguir, um resumo sobre o modelo teórico Binomial!
# >
#
# > **DISTRIBUIÇÃO BINOMIAL - TEORIA:**
#
# > É responsável por modelar uma variável $Y$ definida pelo Número de sucessos em $n$ tentativas, cuja probabilidade de sucesso é dada por $p$. Assim, dizemos que $Y$~$Bin(n,p)$ e lê-se: $Y$ segue uma distribuição binomial com $n$ tentativas e $p$ como probabilidade de sucesso.
#
# > A função de probabilidade nesse caso é dada por:
# $P(Y=y)=\left(
# \begin{array}{c}
#     n \\
#     y
# \end{array}\right) p^y (1-p)^{(n-y)}$
#
# > Para um experimento ter as probabilidade dos números de sucessos modeladas por uma distribuição Binomial, o mesmo precisa ter as seguintes propriedades:
# * é uma contagem de $n$ repetições (ou tentativas ou ensaios) idênticas;
# * cada repetição tem apenas 2 resultados possíveis: um é denominado sucesso e o outro, fracasso;
# * a probabilidade de sucesso para cada ensaio é denominada $p$ e será constante em cada repetição. Então, a probabilidade de fracasso $(1-p)$ também não varia de tentativa para tentativa;
# * As tentativas são independentes.
#
#
# > **DISTRIBUIÇÃO BINOMIAL - PYTHON:** <sup> [https://en.wikipedia.org/wiki/SciPy]
#
# > Algumas funções úteis para desenvolver seu código: <sup> [http://docs.scipy.org/doc/scipy-0.16.1/reference/generated/scipy.stats.binom.html]
# * $P(Y=y)$: `stats.binom.pmf(y, n, p)`
# * $P(Y\leq y)$: `stats.binom.cdf(y, n, p)`
# * $E(Y)$ e $Var(Y)$: `stats.binom.stats(n, p, moments='mv')`

# %%
#item 1
n=3
#item 2
n=7

# %%
#1a
n=3
opcoes=['Falha','NaoFalha']
probabilidade={'Falha':0.05,'NaoFalha':0.95}
comb = itertools.product(opcoes, repeat=n)
espamostral = list(comb)
espamostral
# Out:
# [('Falha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha'),
#  ('Falha', 'NaoFalha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha'),
#  ('NaoFalha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'Falha'),
#  ('NaoFalha', 'NaoFalha', 'NaoFalha')]

# %%
probespaco = []
for f in espamostral:
    proba=1
    for p in f:
        proba*=probabilidade[p]
    probespaco.append(proba)


print('Probabilidade de cada linha do primeiro espaço amostral')    
probespaco
# Out:
# Probabilidade de cada linha do primeiro espaço amostral
# [0.00012500000000000003,
#  0.0023750000000000004,
#  0.0023750000000000004,
#  0.045125,
#  0.0023750000000000004,
#  0.045125,
#  0.045125,
#  0.8573749999999999]

# %%
#1b

valY = {}

for f in range(len(espamostral)):
    y = espamostral[f].count('Falha')
    if y in valY:
        valY[y]+=probespaco
    else:
        valY[y]=probespaco
        
for y in valY:
    print('Falhas:',y,'Probabilidade',valY[y])
# Out:
# Falhas: 3 Probabilidade [0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0 ...
# Falhas: 2 Probabilidade [0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0 ...
# Falhas: 1 Probabilidade [0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0 ...
# Falhas: 0 Probabilidade [0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0.045125, 0.8573749999999999, 0.00012500000000000003, 0.0023750000000000004, 0.0023750000000000004, 0.045125, 0.0023750000000000004, 0.045125, 0 ...

# %%
#1c
stats.binom.stats(n, 0.95, moments='mv')
# Out:
# (array(2.8499999999999996), array(0.1425000000000001))

# %%
print('esperança é 2.85')
# Out:
# esperança é 2.85

# %%
desv=0.1425**0.5
desv
# Out:
# 0.37749172176353746

# %%
print('desvio padrão é 0,37')
# Out:
# desvio padrão é 0,37

# %%
#2a
n=7
opcoes=['Falha','NaoFalha']
probabilidade={'Falha':0.05,'NaoFalha':0.95}
comb = itertools.product(opcoes, repeat=n)
espamostral = list(comb)
espamostral
# Out:
# [('Falha', 'Falha', 'Falha', 'Falha', 'Falha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha'),
#  ('Falha', 'Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha'),
#  ('Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha'),
#  ('Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha'),
#  ('Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha'),
#  ('Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('Falha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha', 'Falha'),
#  ('Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha'),
#  ('Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha'),
#  ('Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha'),
#  ('Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha'),
#  ('Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha'),
#  ('Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('Falha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha'),
#  ('Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha'),
#  ('Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha'),
#  ('Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha'),
#  ('Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha', 'Falha', 'Falha'),
#  ('NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha'),
#  ('NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha'),
#  ('NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha'),
#  ('NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha'),
#  ('NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha'),
#  ('NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('NaoFalha',
#   'Falha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha'),
#  ('NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha'),
#  ('NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha'),
#  ('NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha'),
#  ('NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha', 'Falha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'Falha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'Falha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'Falha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'Falha'),
#  ('NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha', 'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'NaoFalha', 'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'NaoFalha', 'Falha', 'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha', 'NaoFalha', 'NaoFalha', 'NaoFalha', 'Falha', 'Falha', 'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'Falha',
#   'NaoFalha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha',
#   'NaoFalha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha',
#   'NaoFalha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'Falha'),
#  ('NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha',
#   'NaoFalha')]

# %%
#2a
probespaco = []
for f in espamostral:
    proba=1
    for p in f:
        proba*=probabilidade[p]
    probespaco.append(proba)


print('Probabilidade de cada linha do segundo espaço amostral')    
probespaco
# Out:
# Probabilidade de cada linha do segundo espaço amostral
# [7.812500000000004e-10,
#  1.4843750000000005e-08,
#  1.4843750000000007e-08,
#  2.820312500000001e-07,
#  1.4843750000000007e-08,
#  2.820312500000001e-07,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  1.4843750000000007e-08,
#  2.820312500000001e-07,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  1.4843750000000007e-08,
#  2.820312500000001e-07,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  0.00010181328125000002,
#  0.0019344523437500002,
#  1.4843750000000007e-08,
#  2.820312500000001e-07,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  0.00010181328125000002,
#  0.0019344523437500002,
#  2.8203125e-07,
#  5.35859375e-06,
#  5.358593750000001e-06,
#  0.00010181328125,
#  5.358593750000001e-06,
#  0.00010181328125,
#  0.00010181328125,
#  0.0019344523437499997,
#  5.358593750000001e-06,
#  0.00010181328125,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.0019344523437499997,
#  0.03675459453124999,
#  1.4843750000000007e-08,
#  2.820312500000001e-07,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  2.820312500000001e-07,
#  5.358593750000001e-06,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  5.358593750000001e-06,
#  0.00010181328125000001,
#  0.00010181328125000002,
#  0.0019344523437500002,
#  2.8203125e-07,
#  5.35859375e-06,
#  5.358593750000001e-06,
#  0.00010181328125,
#  5.358593750000001e-06,
#  0.00010181328125,
#  0.00010181328125,
#  0.0019344523437499997,
#  5.358593750000001e-06,
#  0.00010181328125,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.0019344523437499997,
#  0.03675459453124999,
#  2.8203125e-07,
#  5.35859375e-06,
#  5.358593750000001e-06,
#  0.00010181328125,
#  5.358593750000001e-06,
#  0.00010181328125,
#  0.00010181328125,
#  0.0019344523437499997,
#  5.358593750000001e-06,
#  0.00010181328125,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.0019344523437499997,
#  0.03675459453124999,
#  5.358593750000001e-06,
#  0.00010181328125,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.0019344523437499997,
#  0.03675459453124999,
#  0.00010181328125,
#  0.0019344523437499997,
#  0.0019344523437500002,
#  0.03675459453125,
#  0.0019344523437499997,
#  0.03675459453124999,
#  0.03675459453124999,
#  0.6983372960937497]

# %% [markdown]
# ___
# ## <font color='blue'>Exercício 2</font>
#
# Esse exercício irá explorar modelos de distribuição de Poisson.
#
# Uma fábrica produz determinado veículo. O gerente de vendas fechou um negócio que implica na produção de pelo menos 110 unidades nos próximos dois meses. Para isso, será construída uma nova linha de montagem com capacidade para produzir em média 50 veículos por mês (considere meses de 30 dias). A linha funcionará ininterruptamente. Além disso, apenas um veículo é produzido por vez. Considere que um modelo Poisson seja adequado para a quantidade de veículos produzidos.
#    1. Qual a probabilidade  da produção ser igual a 100 veículos nos próximos dois meses?
#    2. Qual a probabilidade  da produção ser de pelo menos 100 veículos nos próximos dois meses?
#    3. Qual a probabilidade da produção ser entre 100 e 110 veículos nos próximos dois meses?
#    4. Se forem produzidos de pelo menos 100 veículos no próximo mês, qual a probabilidade do gerente cumprir a meta negociada?
#    5. Caso o prazo seja cumprido, o lucro será da ordem de $250$ mil, caso não seja, o lucro cai para $200$ mil. Qual é o lucro esperado e seu desvio-padrão?
#
# **Observação:** Explore os comandos de `stats.poisson`. <sup>[http://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.poisson.html]
